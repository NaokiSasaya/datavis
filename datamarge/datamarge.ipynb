# %%
import pandas as pd

# %%
happines=pd.read_csv('data/happines.csv')
life=pd.read_csv('data/life span.csv')
master=pd.read_csv('data/master.csv')

pop=pd.read_csv('data/pop.csv')
continent=pd.read_csv('data/continent.csv')
mental=pd.read_csv('data/suicide_total_deaths.csv')
lex=pd.read_csv('data/lex.csv')

# %%
life
# Out:
#      Country name  ISO3  year  Healthy life expectancy at birth
# 0         Denmark   NaN  2008                            68.960
# 1         Denmark   NaN  2009                            69.180
# 2         Denmark   NaN  2010                            69.400
# 3         Denmark   NaN  2011                            69.620
# 4     Switzerland   NaN  2012                            71.520
# ...           ...   ...   ...                               ...
# 2194     Zimbabwe   NaN  2018                            52.625
# 2195     Zimbabwe   NaN  2019                            53.100
# 2196     Zimbabwe   NaN  2020                            53.575
# 2197     Zimbabwe   NaN  2021                            54.050
# 2198     Zimbabwe   NaN  2022                            54.525
#
# [2199 rows x 4 columns]

# %%
import csv

def create_country_iso3_mapping(csv_file):
    country_iso3_mapping = {}
    with open(csv_file, 'r', encoding='utf-8') as file:
        reader = csv.DictReader(file)
        for row in reader:
            country_name = row['Country name']
            iso3_code = row['ISO3']
            country_iso3_mapping[country_name] = iso3_code
    return country_iso3_mapping

# CSVファイルから対応表を作成
csv_file = 'data/master.csv'
country_iso3_mapping = create_country_iso3_mapping(csv_file)

# %%
country_iso3_mapping
# Out:
# {'Afghanistan': 'AFG',
#  'Albania': 'ALB',
#  'Algeria': 'DZA',
#  'American Samoa': 'ASM',
#  'Andorra': 'AND',
#  'Angola': 'AGO',
#  'Anguilla': 'AIA',
#  'Antarctica': 'ATA',
#  'Antigua and Barbuda': 'ATG',
#  'Argentina': 'ARG',
#  'Armenia': 'ARM',
#  'Aruba': 'ABW',
#  'Australia': 'AUS',
#  'Austria': 'AUT',
#  'Azerbaijan': 'AZE',
#  'Bahamas': 'BHS',
#  'Bahrain': 'BHR',
#  'Bangladesh': 'BGD',
#  'Barbados': 'BRB',
#  'Belarus': 'BLR',
#  'Belgium': 'BEL',
#  'Belize': 'BLZ',
#  'Benin': 'BEN',
#  'Bermuda': 'BMU',
#  'Bhutan': 'BTN',
#  'Bolivia, Plurinational State of': 'BOL',
#  'Bolivia': 'BOL',
#  'Bosnia and Herzegovina': 'BIH',
#  'Botswana': 'BWA',
#  'Bouvet Island': 'BVT',
#  'Brazil': 'BRA',
#  'British Indian Ocean Territory': 'IOT',
#  'Brunei Darussalam': 'BRN',
#  'Brunei': 'BRN',
#  'Bulgaria': 'BGR',
#  'Burkina Faso': 'BFA',
#  'Burundi': 'BDI',
#  'Cambodia': 'KHM',
#  'Cameroon': 'CMR',
#  'Canada': 'CAN',
#  'Cape Verde': 'CPV',
#  'Cayman Islands': 'CYM',
#  'Central African Republic': 'CAF',
#  'Chad': 'TCD',
#  'Chile': 'CHL',
#  'China': 'CHN',
#  'Christmas Island': 'CXR',
#  'Cocos (Keeling) Islands': 'CCK',
#  'Colombia': 'COL',
#  'Comoros': 'COM',
#  'Congo (Brazzaville)': 'COG',
#  'Congo (Kinshasa)': 'COD',
#  'Cook Islands': 'COK',
#  'Costa Rica': 'CRI',
#  "Côte d'Ivoire": 'CIV',
#  'Ivory Coast': 'CIV',
#  'Croatia': 'HRV',
#  'Cuba': 'CUB',
#  'Cyprus': 'CYP',
#  'Czech Republic': 'CZE',
#  'Czechia': 'CZE',
#  'Denmark': 'DNK',
#  'Djibouti': 'DJI',
#  'Dominica': 'DMA',
#  'Dominican Republic': 'DOM',
#  'Ecuador': 'ECU',
#  'Egypt': 'EGY',
#  'El Salvador': 'SLV',
#  'Equatorial Guinea': 'GNQ',
#  'Eritrea': 'ERI',
#  'Estonia': 'EST',
#  'Ethiopia': 'ETH',
#  'Falkland Islands (Malvinas)': 'FLK',
#  'Faroe Islands': 'FRO',
#  'Fiji': 'FJI',
#  'Finland': 'FIN',
#  'France': 'FRA',
#  'French Guiana': 'GUF',
#  'French Polynesia': 'PYF',
#  'French Southern Territories': 'ATF',
#  'Gabon': 'GAB',
#  'Gambia': 'GMB',
#  'Georgia': 'GEO',
#  'Germany': 'DEU',
#  'Ghana': 'GHA',
#  'Gibraltar': 'GIB',
#  'Greece': 'GRC',
#  'Greenland': 'GRL',
#  'Grenada': 'GRD',
#  'Guadeloupe': 'GLP',
#  'Guam': 'GUM',
#  'Guatemala': 'GTM',
#  'Guernsey': 'GGY',
#  'Guinea': 'GIN',
#  'Guinea-Bissau': 'GNB',
#  'Guyana': 'GUY',
#  'Haiti': 'HTI',
#  'Heard Island and McDonald Islands': 'HMD',
#  'Holy See (Vatican City State)': 'VAT',
#  'Honduras': 'HND',
#  'Hong Kong': 'HKG',
#  'Hungary': 'HUN',
#  'Iceland': 'ISL',
#  'India': 'IND',
#  'Indonesia': 'IDN',
#  'Iran, Islamic Republic of': 'IRN',
#  'Iraq': 'IRQ',
#  'Ireland': 'IRL',
#  'Isle of Man': 'IMN',
#  'Israel': 'ISR',
#  'Italy': 'ITA',
#  'Jamaica': 'JAM',
#  'Japan': 'JPN',
#  'Jersey': 'JEY',
#  'Jordan': 'JOR',
#  'Kazakhstan': 'KAZ',
#  'Kenya': 'KEN',
#  'Kiribati': 'KIR',
#  "Korea, Democratic People's Republic of": 'PRK',
#  'Korea, Republic of': 'KOR',
#  'South Korea': 'KOR',
#  'Kuwait': 'KWT',
#  'Kyrgyzstan': 'KGZ',
#  "Lao People's Democratic Republic": 'LAO',
#  'Latvia': 'LVA',
#  'Lebanon': 'LBN',
#  'Lesotho': 'LSO',
#  'Liberia': 'LBR',
#  'Libyan Arab Jamahiriya': 'LBY',
#  'Libya': 'LBY',
#  'Liechtenstein': 'LIE',
#  'Lithuania': 'LTU',
#  'Luxembourg': 'LUX',
#  'Macao': 'MAC',
#  'North Macedonia': 'MKD',
#  'Madagascar': 'MDG',
#  'Malawi': 'MWI',
#  'Malaysia': 'MYS',
#  'Maldives': 'MDV',
#  'Mali': 'MLI',
#  'Malta': 'MLT',
#  'Marshall Islands': 'MHL',
#  'Martinique': 'MTQ',
#  'Mauritania': 'MRT',
#  'Mauritius': 'MUS',
#  'Mayotte': 'MYT',
#  'Mexico': 'MEX',
#  'Micronesia, Federated States of': 'FSM',
#  'Moldova, Republic of': 'MDA',
#  'Monaco': 'MCO',
#  'Mongolia': 'MNG',
#  'Montenegro': 'MNE',
#  'Montserrat': 'MSR',
#  'Morocco': 'MAR',
#  'Mozambique': 'MOZ',
#  'Myanmar': 'MMR',
#  'Burma': 'MMR',
#  'Namibia': 'NAM',
#  'Nauru': 'NRU',
#  'Nepal': 'NPL',
#  'Netherlands': 'NLD',
#  'Netherlands Antilles': 'ANT',
#  'New Caledonia': 'NCL',
#  'New Zealand': 'NZL',
#  'Nicaragua': 'NIC',
#  'Niger': 'NER',
#  'Nigeria': 'NGA',
#  'Niue': 'NIU',
#  'Norfolk Island': 'NFK',
#  'Northern Mariana Islands': 'MNP',
#  'Norway': 'NOR',
#  'Oman': 'OMN',
#  'Pakistan': 'PAK',
#  'Palau': 'PLW',
#  'State of Palestinian': 'PSE',
#  'Panama': 'PAN',
#  'Papua New Guinea': 'PNG',
#  'Paraguay': 'PRY',
#  'Peru': 'PER',
#  'Philippines': 'PHL',
#  'Pitcairn': 'PCN',
#  'Poland': 'POL',
#  'Portugal': 'PRT',
#  'Puerto Rico': 'PRI',
#  'Qatar': 'QAT',
#  'Réunion': 'REU',
#  'Romania': 'ROU',
#  'Russian Federation': 'RUS',
#  'Russia': 'RUS',
#  'Rwanda': 'RWA',
#  'Saint Helena, Ascension and Tristan da Cunha': 'SHN',
#  'Saint Kitts and Nevis': 'KNA',
#  'Saint Lucia': 'LCA',
#  'Saint Pierre and Miquelon': 'SPM',
#  'Saint Vincent and the Grenadines': 'VCT',
#  'Saint Vincent & the Grenadines': 'VCT',
#  'St. Vincent and the Grenadines': 'VCT',
#  'Samoa': 'WSM',
#  'San Marino': 'SMR',
#  'Sao Tome and Principe': 'STP',
#  'Saudi Arabia': 'SAU',
#  'Senegal': 'SEN',
#  'Serbia': 'SRB',
#  'Seychelles': 'SYC',
#  'Sierra Leone': 'SLE',
#  'Singapore': 'SGP',
#  'Slovakia': 'SVK',
#  'Slovenia': 'SVN',
#  'Solomon Islands': 'SLB',
#  'Somalia': 'SOM',
#  'South Africa': 'ZAF',
#  'South Georgia and the South Sandwich Islands': 'SGS',
#  'South Sudan': 'SSD',
#  'Spain': 'ESP',
#  'Sri Lanka': 'LKA',
#  'Sudan': 'SDN',
#  'Suriname': 'SUR',
#  'Svalbard and Jan Mayen': 'SJM',
#  'Swaziland': 'SWZ',
#  'Sweden': 'SWE',
#  'Switzerland': 'CHE',
#  'Syrian Arab Republic': 'SYR',
#  'Taiwan Province of China': 'TWN',
#  'Taiwan': 'TWN',
#  'Tajikistan': 'TJK',
#  'Tanzania': 'TZA',
#  'Thailand': 'THA',
#  'Timor-Leste': 'TLS',
#  'Togo': 'TGO',
#  'Tokelau': 'TKL',
#  'Tonga': 'TON',
#  'Trinidad and Tobago': 'TTO',
#  'Tunisia': 'TUN',
#  'Turkey': 'TUR',
#  'Turkmenistan': 'TKM',
#  'Turks and Caicos Islands': 'TCA',
#  'Tuvalu': 'TUV',
#  'Uganda': 'UGA',
#  'Ukraine': 'UKR',
#  'United Arab Emirates': 'ARE',
#  'United Kingdom': 'GBR',
#  'United States': 'USA',
#  'United States Minor Outlying Islands': 'UMI',
#  'Uruguay': 'URY',
#  'Uzbekistan': 'UZB',
#  'Vanuatu': 'VUT',
#  'Venezuela, Bolivarian Republic of': 'VEN',
#  'Venezuela': 'VEN',
#  'Viet Nam': 'VNM',
#  'Vietnam': 'VNM',
#  'Virgin Islands, British': 'VGB',
#  'Virgin Islands, U.S.': 'VIR',
#  'Wallis and Futuna': 'WLF',
#  'Western Sahara': 'ESH',
#  'Yemen': 'YEM',
#  'Zambia': 'ZMB',
#  'Zimbabwe': 'ZWE',
#  'Kosovo': 'KOS',
#  'Moldova': 'MDA',
#  'Hong Kong S.A.R. of China': 'HKG',
#  'Iran': 'IRN',
#  'Laos': 'LAO',
#  'Syria': 'SYR',
#  'Eswatini': 'SWZ',
#  '': ''}

# %%
# 対応表の使用例
country_name = 'Japan'
iso3_code = country_iso3_mapping.get(country_name)
print(iso3_code)  # 結果: AFG
# Out:
# JPN

# %%
life['ISO3']=life['ISO3'].astype(object)

# %%
for index,row in lex.iterrows():
    country=row['country']
    iso3=country_iso3_mapping.get(country)
    print(country,iso3)
    lex.loc[index,'ISO3']=iso3
# Out:
# Afghanistan AFG
# Angola AGO
# Albania ALB
# Andorra AND
# United Arab Emirates ARE
# Argentina ARG
# Armenia ARM
# Antigua and Barbuda ATG
# Australia AUS
# Austria AUT
# Azerbaijan AZE
# Burundi BDI
# Belgium BEL
# Benin BEN
# Burkina Faso BFA
# Bangladesh BGD
# Bulgaria BGR
# Bahrain BHR
# Bahamas BHS
# Bosnia and Herzegovina BIH
# Belarus BLR
# Belize BLZ
# Bolivia BOL
# Brazil BRA
# Barbados BRB
# Brunei BRN
# Bhutan BTN
# Botswana BWA
# Central African Republic CAF
# Canada CAN
# Switzerland CHE
# Chile CHL
# China CHN
# Cote d'Ivoire None
# Cameroon CMR
# Congo, Dem. Rep. None
# Congo, Rep. None
# Colombia COL
# Comoros COM
# Cape Verde CPV
# Costa Rica CRI
# Cuba CUB
# Cyprus CYP
# Czech Republic CZE
# Germany DEU
# Djibouti DJI
# Dominica DMA
# Denmark DNK
# Dominican Republic DOM
# Algeria DZA
# Ecuador ECU
# Egypt EGY
# Eritrea ERI
# Spain ESP
# Estonia EST
# Ethiopia ETH
# Finland FIN
# Fiji FJI
# France FRA
# Micronesia, Fed. Sts. None
# Gabon GAB
# United Kingdom GBR
# Georgia GEO
# Ghana GHA
# Guinea GIN
# Gambia GMB
# Guinea-Bissau GNB
# Equatorial Guinea GNQ
# Greece GRC
# Grenada GRD
# Guatemala GTM
# Guyana GUY
# Hong Kong, China None
# Honduras HND
# Croatia HRV
# Haiti HTI
# Hungary HUN
# Indonesia IDN
# India IND
# Ireland IRL
# Iran IRN
# Iraq IRQ
# Iceland ISL
# Israel ISR
# Italy ITA
# Jamaica JAM
# Jordan JOR
# Japan JPN
# Kazakhstan KAZ
# Kenya KEN
# Kyrgyz Republic None
# Cambodia KHM
# Kiribati KIR
# St. Kitts and Nevis None
# South Korea KOR
# Kuwait KWT
# Lao None
# Lebanon LBN
# Liberia LBR
# Libya LBY
# St. Lucia None
# Sri Lanka LKA
# Lesotho LSO
# Lithuania LTU
# Luxembourg LUX
# Latvia LVA
# Morocco MAR
# Monaco MCO
# Moldova MDA
# Madagascar MDG
# Maldives MDV
# Mexico MEX
# Marshall Islands MHL
# North Macedonia MKD
# Mali MLI
# Malta MLT
# Myanmar MMR
# Montenegro MNE
# Mongolia MNG
# Mozambique MOZ
# Mauritania MRT
# Mauritius MUS
# Malawi MWI
# Malaysia MYS
# Namibia NAM
# Niger NER
# Nigeria NGA
# Nicaragua NIC
# Netherlands NLD
# Norway NOR
# Nepal NPL
# Nauru NRU
# New Zealand NZL
# Oman OMN
# Pakistan PAK
# Panama PAN
# Peru PER
# Philippines PHL
# Palau PLW
# Papua New Guinea PNG
# Poland POL
# North Korea None
# Portugal PRT
# Paraguay PRY
# Palestine None
# Qatar QAT
# Romania ROU
# Russia RUS
# Rwanda RWA
# Saudi Arabia SAU
# Sudan SDN
# Senegal SEN
# Singapore SGP
# Solomon Islands SLB
# Sierra Leone SLE
# El Salvador SLV
# San Marino SMR
# Somalia SOM
# Serbia SRB
# South Sudan SSD
# Sao Tome and Principe STP
# Suriname SUR
# Slovak Republic None
# Slovenia SVN
# Sweden SWE
# Eswatini SWZ
# Seychelles SYC
# Syria SYR
# Chad TCD
# Togo TGO
# Thailand THA
# Tajikistan TJK
# Turkmenistan TKM
# Timor-Leste TLS
# Tonga TON
# Trinidad and Tobago TTO
# Tunisia TUN
# Turkey TUR
# Tuvalu TUV
# Taiwan TWN
# Tanzania TZA
# Uganda UGA
# Ukraine UKR
# Uruguay URY
# United States USA
# Uzbekistan UZB
# St. Vincent and the Grenadines VCT
# Venezuela VEN
# Vietnam VNM
# Vanuatu VUT
# Samoa WSM
# Yemen YEM
# South Africa ZAF
# Zambia ZMB
# Zimbabwe ZWE

# %%
lex.to_csv('life_iso3.csv')

# %%
for index,row in pop.iterrows():
    country=row['country']
    iso3=country_iso3_mapping.get(country)
    print(country,iso3)
    pop.loc[index,'ISO3']=iso3
# Out:
# Afghanistan AFG
# Angola AGO
# Albania ALB
# Andorra AND
# United Arab Emirates ARE
# Argentina ARG
# Armenia ARM
# Antigua and Barbuda ATG
# Australia AUS
# Austria AUT
# Azerbaijan AZE
# Burundi BDI
# Belgium BEL
# Benin BEN
# Burkina Faso BFA
# Bangladesh BGD
# Bulgaria BGR
# Bahrain BHR
# Bahamas BHS
# Bosnia and Herzegovina BIH
# Belarus BLR
# Belize BLZ
# Bolivia BOL
# Brazil BRA
# Barbados BRB
# Brunei BRN
# Bhutan BTN
# Botswana BWA
# Central African Republic CAF
# Canada CAN
# Switzerland CHE
# Chile CHL
# China CHN
# Cote d'Ivoire None
# Cameroon CMR
# Congo, Dem. Rep. None
# Congo, Rep. None
# Colombia COL
# Comoros COM
# Cape Verde CPV
# Costa Rica CRI
# Cuba CUB
# Cyprus CYP
# Czech Republic CZE
# Germany DEU
# Djibouti DJI
# Dominica DMA
# Denmark DNK
# Dominican Republic DOM
# Algeria DZA
# Ecuador ECU
# Egypt EGY
# Eritrea ERI
# Spain ESP
# Estonia EST
# Ethiopia ETH
# Finland FIN
# Fiji FJI
# France FRA
# Micronesia, Fed. Sts. None
# Gabon GAB
# United Kingdom GBR
# Georgia GEO
# Ghana GHA
# Guinea GIN
# Gambia GMB
# Guinea-Bissau GNB
# Equatorial Guinea GNQ
# Greece GRC
# Grenada GRD
# Guatemala GTM
# Guyana GUY
# Hong Kong, China None
# Honduras HND
# Holy See None
# Croatia HRV
# Haiti HTI
# Hungary HUN
# Indonesia IDN
# India IND
# Ireland IRL
# Iran IRN
# Iraq IRQ
# Iceland ISL
# Israel ISR
# Italy ITA
# Jamaica JAM
# Jordan JOR
# Japan JPN
# Kazakhstan KAZ
# Kenya KEN
# Kyrgyz Republic None
# Cambodia KHM
# Kiribati KIR
# St. Kitts and Nevis None
# South Korea KOR
# Kuwait KWT
# Lao None
# Lebanon LBN
# Liberia LBR
# Libya LBY
# St. Lucia None
# Liechtenstein LIE
# Sri Lanka LKA
# Lesotho LSO
# Lithuania LTU
# Luxembourg LUX
# Latvia LVA
# Morocco MAR
# Monaco MCO
# Moldova MDA
# Madagascar MDG
# Maldives MDV
# Mexico MEX
# Marshall Islands MHL
# North Macedonia MKD
# Mali MLI
# Malta MLT
# Myanmar MMR
# Montenegro MNE
# Mongolia MNG
# Mozambique MOZ
# Mauritania MRT
# Mauritius MUS
# Malawi MWI
# Malaysia MYS
# Namibia NAM
# Niger NER
# Nigeria NGA
# Nicaragua NIC
# Netherlands NLD
# Norway NOR
# Nepal NPL
# Nauru NRU
# New Zealand NZL
# Oman OMN
# Pakistan PAK
# Panama PAN
# Peru PER
# Philippines PHL
# Palau PLW
# Papua New Guinea PNG
# Poland POL
# North Korea None
# Portugal PRT
# Paraguay PRY
# Palestine None
# Qatar QAT
# Romania ROU
# Russia RUS
# Rwanda RWA
# Saudi Arabia SAU
# Sudan SDN
# Senegal SEN
# Singapore SGP
# Solomon Islands SLB
# Sierra Leone SLE
# El Salvador SLV
# San Marino SMR
# Somalia SOM
# Serbia SRB
# South Sudan SSD
# Sao Tome and Principe STP
# Suriname SUR
# Slovak Republic None
# Slovenia SVN
# Sweden SWE
# Eswatini SWZ
# Seychelles SYC
# Syria SYR
# Chad TCD
# Togo TGO
# Thailand THA
# Tajikistan TJK
# Turkmenistan TKM
# Timor-Leste TLS
# Tonga TON
# Trinidad and Tobago TTO
# Tunisia TUN
# Turkey TUR
# Tuvalu TUV
# Taiwan TWN
# Tanzania TZA
# Uganda UGA
# Ukraine UKR
# Uruguay URY
# United States USA
# Uzbekistan UZB
# St. Vincent and the Grenadines VCT
# Venezuela VEN
# Vietnam VNM
# Vanuatu VUT
# Samoa WSM
# Yemen YEM
# South Africa ZAF
# Zambia ZMB
# Zimbabwe ZWE

# %%
pop.to_csv('pop_iso3.csv')

# %%
for index,row in mental.iterrows():
    country=row['country']
    iso3=country_iso3_mapping.get(country)
    print(country,iso3)
    mental.loc[index,'ISO3']=iso3
# Out:
# Afghanistan AFG
# Angola AGO
# Albania ALB
# Andorra AND
# United Arab Emirates ARE
# Argentina ARG
# Armenia ARM
# American Samoa ASM
# Antigua and Barbuda ATG
# Australia AUS
# Austria AUT
# Azerbaijan AZE
# Burundi BDI
# Belgium BEL
# Benin BEN
# Burkina Faso BFA
# Bangladesh BGD
# Bulgaria BGR
# Bahrain BHR
# Bahamas BHS
# Bosnia and Herzegovina BIH
# Belarus BLR
# Belize BLZ
# Bermuda BMU
# Bolivia BOL
# Brazil BRA
# Barbados BRB
# Brunei BRN
# Bhutan BTN
# Botswana BWA
# Central African Republic CAF
# Canada CAN
# Switzerland CHE
# Chile CHL
# China CHN
# Cote d'Ivoire None
# Cameroon CMR
# Congo, Dem. Rep. None
# Congo, Rep. None
# Cook Is None
# Colombia COL
# Comoros COM
# Cape Verde CPV
# Costa Rica CRI
# Cuba CUB
# Cyprus CYP
# Czech Republic CZE
# Germany DEU
# Djibouti DJI
# Dominica DMA
# Denmark DNK
# Dominican Republic DOM
# Algeria DZA
# Ecuador ECU
# Egypt EGY
# Eritrea ERI
# Spain ESP
# Estonia EST
# Ethiopia ETH
# Finland FIN
# Fiji FJI
# France FRA
# Micronesia, Fed. Sts. None
# Gabon GAB
# United Kingdom GBR
# Georgia GEO
# Ghana GHA
# Guinea GIN
# Gambia GMB
# Guinea-Bissau GNB
# Equatorial Guinea GNQ
# Greece GRC
# Grenada GRD
# Greenland GRL
# Guatemala GTM
# Guam GUM
# Guyana GUY
# Honduras HND
# Croatia HRV
# Haiti HTI
# Hungary HUN
# Indonesia IDN
# India IND
# Ireland IRL
# Iran IRN
# Iraq IRQ
# Iceland ISL
# Israel ISR
# Italy ITA
# Jamaica JAM
# Jordan JOR
# Japan JPN
# Kazakhstan KAZ
# Kenya KEN
# Kyrgyz Republic None
# Cambodia KHM
# Kiribati KIR
# St. Kitts and Nevis None
# South Korea KOR
# Kuwait KWT
# Lao None
# Lebanon LBN
# Liberia LBR
# Libya LBY
# St. Lucia None
# Sri Lanka LKA
# Lesotho LSO
# Lithuania LTU
# Luxembourg LUX
# Latvia LVA
# Morocco MAR
# Monaco MCO
# Moldova MDA
# Madagascar MDG
# Maldives MDV
# Mexico MEX
# Marshall Islands MHL
# North Macedonia MKD
# Mali MLI
# Malta MLT
# Myanmar MMR
# Montenegro MNE
# Mongolia MNG
# Northern Mariana Islands MNP
# Mozambique MOZ
# Mauritania MRT
# Mauritius MUS
# Malawi MWI
# Malaysia MYS
# Namibia NAM
# Niger NER
# Nigeria NGA
# Nicaragua NIC
# Niue NIU
# Netherlands NLD
# Norway NOR
# Nepal NPL
# Nauru NRU
# New Zealand NZL
# Oman OMN
# Pakistan PAK
# Panama PAN
# Peru PER
# Philippines PHL
# Palau PLW
# Papua New Guinea PNG
# Poland POL
# Puerto Rico PRI
# North Korea None
# Portugal PRT
# Paraguay PRY
# Palestine None
# Qatar QAT
# Romania ROU
# Russia RUS
# Rwanda RWA
# Saudi Arabia SAU
# Sudan SDN
# Senegal SEN
# Singapore SGP
# Solomon Islands SLB
# Sierra Leone SLE
# El Salvador SLV
# San Marino SMR
# Somalia SOM
# Serbia SRB
# South Sudan SSD
# Sao Tome and Principe STP
# Suriname SUR
# Slovak Republic None
# Slovenia SVN
# Sweden SWE
# Eswatini SWZ
# Seychelles SYC
# Syria SYR
# Chad TCD
# Togo TGO
# Thailand THA
# Tajikistan TJK
# Tokelau TKL
# Turkmenistan TKM
# Timor-Leste TLS
# Tonga TON
# Trinidad and Tobago TTO
# Tunisia TUN
# Turkey TUR
# Tuvalu TUV
# Taiwan TWN
# Tanzania TZA
# Uganda UGA
# Ukraine UKR
# Uruguay URY
# United States USA
# Uzbekistan UZB
# St. Vincent and the Grenadines VCT
# Venezuela VEN
# Virgin Islands (U.S.) None
# Vietnam VNM
# Vanuatu VUT
# Samoa WSM
# Yemen YEM
# South Africa ZAF
# Zambia ZMB
# Zimbabwe ZWE

# %%
mental.to_csv('mental_iso3.csv')

# %%
happines['ISO3']=happines['ISO3'].astype(object)

# %%
for index,row in happines.iterrows():
    country=row['Country name']
    iso3=country_iso3_mapping.get(country)
    print(country,iso3)
    happines.loc[index,'ISO3']=iso3
# Out:
# Finland FIN
# Denmark DNK
# Iceland ISL
# Israel ISR
# Netherlands NLD
# Sweden SWE
# Norway NOR
# Switzerland CHE
# Luxembourg LUX
# New Zealand NZL
# Austria AUT
# Australia AUS
# Canada CAN
# Ireland IRL
# United States USA
# Germany DEU
# Belgium BEL
# Czechia CZE
# United Kingdom GBR
# Lithuania LTU
# France FRA
# Slovenia SVN
# Costa Rica CRI
# Romania ROU
# Singapore SGP
# United Arab Emirates ARE
# Taiwan Province of China TWN
# Uruguay URY
# Slovakia SVK
# Saudi Arabia SAU
# Estonia EST
# Spain ESP
# Italy ITA
# Kosovo KOS
# Chile CHL
# Mexico MEX
# Malta MLT
# Panama PAN
# Poland POL
# Nicaragua NIC
# Latvia LVA
# Bahrain BHR
# Guatemala GTM
# Kazakhstan KAZ
# Serbia SRB
# Cyprus CYP
# Japan JPN
# Croatia HRV
# Brazil BRA
# El Salvador SLV
# Hungary HUN
# Argentina ARG
# Honduras HND
# Uzbekistan UZB
# Malaysia MYS
# Portugal PRT
# South Korea KOR
# Greece GRC
# Mauritius MUS
# Thailand THA
# Mongolia MNG
# Kyrgyzstan KGZ
# Moldova MDA
# China CHN
# Vietnam VNM
# Paraguay PRY
# Montenegro MNE
# Jamaica JAM
# Bolivia BOL
# Russia RUS
# Bosnia and Herzegovina BIH
# Colombia COL
# Dominican Republic DOM
# Ecuador ECU
# Peru PER
# Philippines PHL
# Bulgaria BGR
# Nepal NPL
# Armenia ARM
# Tajikistan TJK
# Algeria DZA
# Hong Kong S.A.R. of China HKG
# Albania ALB
# Indonesia IDN
# South Africa ZAF
# Congo (Brazzaville) COG
# North Macedonia MKD
# Venezuela VEN
# Laos LAO
# Georgia GEO
# Guinea GIN
# Ukraine UKR
# Ivory Coast CIV
# Gabon GAB
# Nigeria NGA
# Cameroon CMR
# Mozambique MOZ
# Iraq IRQ
# State of Palestine None
# Morocco MAR
# Iran IRN
# Senegal SEN
# Mauritania MRT
# Burkina Faso BFA
# Namibia NAM
# Turkiye None
# Ghana GHA
# Pakistan PAK
# Niger NER
# Tunisia TUN
# Kenya KEN
# Sri Lanka LKA
# Uganda UGA
# Chad TCD
# Cambodia KHM
# Benin BEN
# Myanmar MMR
# Bangladesh BGD
# Gambia GMB
# Mali MLI
# Egypt EGY
# Togo TGO
# Jordan JOR
# Ethiopia ETH
# Liberia LBR
# India IND
# Madagascar MDG
# Zambia ZMB
# Tanzania TZA
# Comoros COM
# Malawi MWI
# Botswana BWA
# Congo (Kinshasa) COD
# Zimbabwe ZWE
# Sierra Leone SLE
# Lebanon LBN
# Afghanistan AFG
# Finland FIN
# Denmark DNK
# Iceland ISL
# Switzerland CHE
# Netherlands NLD
# Luxembourg* None
# Sweden SWE
# Norway NOR
# Israel ISR
# New Zealand NZL
# Austria AUT
# Australia AUS
# Ireland IRL
# Germany DEU
# Canada CAN
# United States USA
# United Kingdom GBR
# Czechia CZE
# Belgium BEL
# France FRA
# Bahrain BHR
# Slovenia SVN
# Costa Rica CRI
# United Arab Emirates ARE
# Saudi Arabia SAU
# Taiwan Province of China TWN
# Singapore SGP
# Romania ROU
# Spain ESP
# Uruguay URY
# Italy ITA
# Kosovo KOS
# Malta MLT
# Lithuania LTU
# Slovakia SVK
# Estonia EST
# Panama PAN
# Brazil BRA
# Guatemala* None
# Kazakhstan KAZ
# Cyprus CYP
# Latvia LVA
# Serbia SRB
# Chile CHL
# Nicaragua NIC
# Mexico MEX
# Croatia HRV
# Poland POL
# El Salvador SLV
# Kuwait* None
# Hungary HUN
# Mauritius MUS
# Uzbekistan UZB
# Japan JPN
# Honduras HND
# Portugal PRT
# Argentina ARG
# Greece GRC
# South Korea KOR
# Philippines PHL
# Thailand THA
# Moldova MDA
# Jamaica JAM
# Kyrgyzstan KGZ
# Belarus* None
# Colombia COL
# Bosnia and Herzegovina BIH
# Mongolia MNG
# Dominican Republic DOM
# Malaysia MYS
# Bolivia BOL
# China CHN
# Paraguay PRY
# Peru PER
# Montenegro MNE
# Ecuador ECU
# Vietnam VNM
# Turkmenistan* None
# North Cyprus* None
# Russia RUS
# Hong Kong S.A.R. of China HKG
# Armenia ARM
# Tajikistan TJK
# Nepal NPL
# Bulgaria BGR
# Libya* None
# Indonesia IDN
# Ivory Coast CIV
# North Macedonia MKD
# Albania ALB
# South Africa ZAF
# Azerbaijan* None
# Gambia* None
# Bangladesh BGD
# Laos LAO
# Algeria DZA
# Liberia* None
# Ukraine UKR
# Congo None
# Morocco MAR
# Mozambique MOZ
# Cameroon CMR
# Senegal SEN
# Niger* None
# Georgia GEO
# Gabon GAB
# Iraq IRQ
# Venezuela VEN
# Guinea GIN
# Iran IRN
# Ghana GHA
# Turkey TUR
# Burkina Faso BFA
# Cambodia KHM
# Benin BEN
# Comoros* None
# Uganda UGA
# Nigeria NGA
# Kenya KEN
# Tunisia TUN
# Pakistan PAK
# Palestinian Territories* None
# Mali MLI
# Namibia NAM
# Eswatini, Kingdom of* None
# Myanmar MMR
# Sri Lanka LKA
# Madagascar* None
# Egypt EGY
# Chad* None
# Ethiopia ETH
# Yemen* None
# Mauritania* None
# Jordan JOR
# Togo TGO
# India IND
# Zambia ZMB
# Malawi MWI
# Tanzania TZA
# Sierra Leone SLE
# Lesotho* None
# Botswana* None
# Rwanda* None
# Zimbabwe ZWE
# Lebanon LBN
# Afghanistan AFG
# xx None
# Finland FIN
# Denmark DNK
# Switzerland CHE
# Iceland ISL
# Netherlands NLD
# Norway NOR
# Sweden SWE
# Luxembourg LUX
# New Zealand NZL
# Austria AUT
# Australia AUS
# Israel ISR
# Germany DEU
# Canada CAN
# Ireland IRL
# Costa Rica CRI
# United Kingdom GBR
# Czech Republic CZE
# United States USA
# Belgium BEL
# France FRA
# Bahrain BHR
# Malta MLT
# Taiwan Province of China TWN
# United Arab Emirates ARE
# Saudi Arabia SAU
# Spain ESP
# Italy ITA
# Slovenia SVN
# Guatemala GTM
# Uruguay URY
# Singapore SGP
# Kosovo KOS
# Slovakia SVK
# Brazil BRA
# Mexico MEX
# Jamaica JAM
# Lithuania LTU
# Cyprus CYP
# Estonia EST
# Panama PAN
# Uzbekistan UZB
# Chile CHL
# Poland POL
# Kazakhstan KAZ
# Romania ROU
# Kuwait KWT
# Serbia SRB
# El Salvador SLV
# Mauritius MUS
# Latvia LVA
# Colombia COL
# Hungary HUN
# Thailand THA
# Nicaragua NIC
# Japan JPN
# Argentina ARG
# Portugal PRT
# Honduras HND
# Croatia HRV
# Philippines PHL
# South Korea KOR
# Peru PER
# Bosnia and Herzegovina BIH
# Moldova MDA
# Ecuador ECU
# Kyrgyzstan KGZ
# Greece GRC
# Bolivia BOL
# Mongolia MNG
# Paraguay PRY
# Montenegro MNE
# Dominican Republic DOM
# North Cyprus None
# Belarus BLR
# Russia RUS
# Hong Kong S.A.R. of China HKG
# Tajikistan TJK
# Vietnam VNM
# Libya LBY
# Malaysia MYS
# Indonesia IDN
# Congo (Brazzaville) COG
# China CHN
# Ivory Coast CIV
# Armenia ARM
# Nepal NPL
# Bulgaria BGR
# Maldives MDV
# Azerbaijan AZE
# Cameroon CMR
# Senegal SEN
# Albania ALB
# North Macedonia MKD
# Ghana GHA
# Niger NER
# Turkmenistan TKM
# Gambia GMB
# Benin BEN
# Laos LAO
# Bangladesh BGD
# Guinea GIN
# South Africa ZAF
# Turkey TUR
# Pakistan PAK
# Morocco MAR
# Venezuela VEN
# Georgia GEO
# Algeria DZA
# Ukraine UKR
# Iraq IRQ
# Gabon GAB
# Burkina Faso BFA
# Cambodia KHM
# Mozambique MOZ
# Nigeria NGA
# Mali MLI
# Iran IRN
# Uganda UGA
# Liberia LBR
# Kenya KEN
# Tunisia TUN
# Lebanon LBN
# Namibia NAM
# Palestinian Territories None
# Myanmar MMR
# Jordan JOR
# Chad TCD
# Sri Lanka LKA
# Swaziland SWZ
# Comoros COM
# Egypt EGY
# Ethiopia ETH
# Mauritania MRT
# Madagascar MDG
# Togo TGO
# Zambia ZMB
# Sierra Leone SLE
# India IND
# Burundi BDI
# Yemen YEM
# Tanzania TZA
# Haiti HTI
# Malawi MWI
# Lesotho LSO
# Botswana BWA
# Rwanda RWA
# Zimbabwe ZWE
# Afghanistan AFG
# Finland FIN
# Denmark DNK
# Switzerland CHE
# Iceland ISL
# Norway NOR
# Netherlands NLD
# Sweden SWE
# New Zealand NZL
# Austria AUT
# Luxembourg LUX
# Canada CAN
# Australia AUS
# United Kingdom GBR
# Israel ISR
# Costa Rica CRI
# Ireland IRL
# Germany DEU
# United States USA
# Czech Republic CZE
# Belgium BEL
# United Arab Emirates ARE
# Malta MLT
# France FRA
# Mexico MEX
# Taiwan Province of China TWN
# Uruguay URY
# Saudi Arabia SAU
# Spain ESP
# Guatemala GTM
# Italy ITA
# Singapore SGP
# Brazil BRA
# Slovenia SVN
# El Salvador SLV
# Kosovo KOS
# Panama PAN
# Slovakia SVK
# Uzbekistan UZB
# Chile CHL
# Bahrain BHR
# Lithuania LTU
# Trinidad and Tobago TTO
# Poland POL
# Colombia COL
# Cyprus CYP
# Nicaragua NIC
# Romania ROU
# Kuwait KWT
# Mauritius MUS
# Kazakhstan KAZ
# Estonia EST
# Philippines PHL
# Hungary HUN
# Thailand THA
# Argentina ARG
# Honduras HND
# Latvia LVA
# Ecuador ECU
# Portugal PRT
# Jamaica JAM
# South Korea KOR
# Japan JPN
# Peru PER
# Serbia SRB
# Bolivia BOL
# Pakistan PAK
# Paraguay PRY
# Dominican Republic DOM
# Bosnia and Herzegovina BIH
# Moldova MDA
# Tajikistan TJK
# Montenegro MNE
# Russia RUS
# Kyrgyzstan KGZ
# Belarus BLR
# North Cyprus None
# Greece GRC
# Hong Kong S.A.R. of China HKG
# Croatia HRV
# Libya LBY
# Mongolia MNG
# Malaysia MYS
# Vietnam VNM
# Indonesia IDN
# Ivory Coast CIV
# Benin BEN
# Maldives MDV
# Congo (Brazzaville) COG
# Azerbaijan AZE
# Macedonia None
# Ghana GHA
# Nepal NPL
# Turkey TUR
# China CHN
# Turkmenistan TKM
# Bulgaria BGR
# Morocco MAR
# Cameroon CMR
# Venezuela VEN
# Algeria DZA
# Senegal SEN
# Guinea GIN
# Niger NER
# Laos LAO
# Albania ALB
# Cambodia KHM
# Bangladesh BGD
# Gabon GAB
# South Africa ZAF
# Iraq IRQ
# Lebanon LBN
# Burkina Faso BFA
# Gambia GMB
# Mali MLI
# Nigeria NGA
# Armenia ARM
# Georgia GEO
# Iran IRN
# Jordan JOR
# Mozambique MOZ
# Kenya KEN
# Namibia NAM
# Ukraine UKR
# Liberia LBR
# Palestinian Territories None
# Uganda UGA
# Chad TCD
# Tunisia TUN
# Mauritania MRT
# Sri Lanka LKA
# Congo (Kinshasa) COD
# Swaziland SWZ
# Myanmar MMR
# Comoros COM
# Togo TGO
# Ethiopia ETH
# Madagascar MDG
# Egypt EGY
# Sierra Leone SLE
# Burundi BDI
# Zambia ZMB
# Haiti HTI
# Lesotho LSO
# India IND
# Malawi MWI
# Yemen YEM
# Botswana BWA
# Tanzania TZA
# Central African Republic CAF
# Rwanda RWA
# Zimbabwe ZWE
# South Sudan SSD
# Afghanistan AFG

# %%
happines.to_csv('happines_iso3.csv')
